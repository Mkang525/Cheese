# %%
import pandas as pd
import os
import csv

# %%
file = "cheese_csv/ambert.csv"
file1= "cheese_csv/beaufort.csv"
file2= "cheese_csv/bleudauvergne.csv"
file3= "cheese_csv/boursin.csv"
file4= "cheese_csv/brie.csv"
file5= "cheese_csv/burrata.csv"
file6= "cheese_csv/cabrales.csv"
file7= "cheese_csv/cambozola.csv"
file8= "cheese_csv/camembert.csv"
file9= "cheese_csv/cantal.csv"
file10= "cheese_csv/chaource.csv"
file11= "cheese_csv/chaumes.csv"
file12= "cheese_csv/cheddar.csv"
file13= "cheese_csv/chevre.csv"
file14= "cheese_csv/comte.csv"
file15= "cheese_csv/crescenza.csv"
file16= "cheese_csv/crottin.csv"
file17= "cheese_csv/danishblue.csv"
file18= "cheese_csv/doublegloucester.csv"
file19= "cheese_csv/edam.csv"
file20= "cheese_csv/epoisses.csv"
file21= "cheese_csv/feta.csv"
file22= "cheese_csv/fontina.csv"
file23= "cheese_csv/gorgonzola.csv"
file24= "cheese_csv/gouda.csv"
file25= "cheese_csv/granapadano.csv"
file26= "cheese_csv/gruyere.csv"
file27= "cheese_csv/havarti.csv"
file28= "cheese_csv/langres.csv"
file29= "cheese_csv/livarot.csv"
file30= "cheese_csv/manchego.csv"
file31= "cheese_csv/marscapone.csv"
file32= "cheese_csv/mimolette.csv"
file33= "cheese_csv/morbier.csv"
file34= "cheese_csv/mozzarella.csv"
file35= "cheese_csv/munster.csv"
file36= "cheese_csv/neuchatel.csv"
file37= "cheese_csv/parmesan.csv"
file38= "cheese_csv/pecorino.csv"
file39= "cheese_csv/provolone.csv"
file40= "cheese_csv/reblochon.csv"
file41= "cheese_csv/ricotta.csv"
file42= "cheese_csv/roquefort.csv"
file43= "cheese_csv/sbrinz.csv"
file44= "cheese_csv/sellessurcher.csv"
file45= "cheese_csv/stilton.csv"
file46= "cheese_csv/taleggio.csv"

# %%
ambert = pd.read_csv("cheese_csv/ambert.csv", encoding='ISO-8859-1')
beaufort= pd.read_csv(file1, encoding='ISO-8859-1')
bleudauvergne=pd.read_csv(file2, encoding='ISO-8859-1')
boursin=pd.read_csv(file3, encoding='ISO-8859-1')
brie=pd.read_csv(file4, encoding='ISO-8859-1')
burrata=pd.read_csv(file5, encoding='ISO-8859-1')
cabrales=pd.read_csv(file6, encoding='ISO-8859-1')
cambozola=pd.read_csv(file7, encoding='ISO-8859-1')
camembert=pd.read_csv(file8, encoding='ISO-8859-1')
cantal=pd.read_csv(file9, encoding='ISO-8859-1')
chaource=pd.read_csv(file10, encoding='ISO-8859-1')
chaumes=pd.read_csv(file11, encoding='ISO-8859-1')
cheddar=pd.read_csv(file12, encoding='ISO-8859-1')
chevre=pd.read_csv(file13, encoding='ISO-8859-1')
comte=pd.read_csv(file14, encoding='ISO-8859-1')
crescenza=pd.read_csv(file15, encoding='ISO-8859-1')
crottin=pd.read_csv(file16, encoding='ISO-8859-1')
danishblue=pd.read_csv(file17, encoding='ISO-8859-1')
doublegloucester=pd.read_csv(file18, encoding='ISO-8859-1')
edam=pd.read_csv(file19, encoding='ISO-8859-1')
epoisses=pd.read_csv(file20, encoding='ISO-8859-1')
feta=pd.read_csv(file21, encoding='ISO-8859-1')
fontina=pd.read_csv(file22, encoding='ISO-8859-1')
gorgonzola=pd.read_csv(file23, encoding='ISO-8859-1')
gouda=pd.read_csv(file24, encoding='ISO-8859-1')
granapadano=pd.read_csv(file25, encoding='ISO-8859-1')
gruyere=pd.read_csv(file26, encoding='ISO-8859-1')
havarti=pd.read_csv(file27, encoding='ISO-8859-1')
langres=pd.read_csv(file28, encoding='ISO-8859-1')
livarot=pd.read_csv(file29, encoding='ISO-8859-1')
manchego=pd.read_csv(file30, encoding='ISO-8859-1')
marscapone=pd.read_csv(file31, encoding='ISO-8859-1')
mimolette=pd.read_csv(file32, encoding='ISO-8859-1')
morbier=pd.read_csv(file33, encoding='ISO-8859-1')
mozzarella=pd.read_csv(file34, encoding='ISO-8859-1')
munster=pd.read_csv(file35, encoding='ISO-8859-1')
neuchatel=pd.read_csv(file36, encoding='ISO-8859-1')
parmesan=pd.read_csv(file37, encoding='ISO-8859-1')
pecorino=pd.read_csv(file38, encoding='ISO-8859-1')
provolone=pd.read_csv(file39, encoding='ISO-8859-1')
reblochon=pd.read_csv(file40, encoding='ISO-8859-1')
ricotta=pd.read_csv(file41, encoding='ISO-8859-1')
roquefort=pd.read_csv(file42, encoding='ISO-8859-1')
sbrinz=pd.read_csv(file43, encoding='ISO-8859-1')
sellessurcher=pd.read_csv(file44, encoding='ISO-8859-1')
stilton=pd.read_csv(file45, encoding='ISO-8859-1')
taleggio=pd.read_csv(file46, encoding='ISO-8859-1')

# %%
ambert=ambert.dropna()
beaufort=beaufort.dropna()
bleudauvergne=bleudauvergne.dropna()
boursin=boursin.dropna()
brie=brie.dropna()
burrata=burrata.dropna()
cabrales=cabrales.dropna()
cambozola=cambozola.dropna()
camembert=camembert.dropna()
cantal=cantal.dropna()
chaource=chaource.dropna()
chaumes=chaumes.dropna()
cheddar=cheddar.dropna()
chevre=chevre.dropna()
comte=comte.dropna()
crescenza=crescenza.dropna()
crottin=crottin.dropna()
danishblue=danishblue.dropna()
doublegloucester=doublegloucester.dropna()
edam=edam.dropna()
epoisses=epoisses.dropna()
feta=feta.dropna()
fontina=fontina.dropna()
gorgonzola=gorgonzola.dropna()
gouda=gouda.dropna()
granapadano=granapadano.dropna()
gruyere=gruyere.dropna()
havarti=havarti.dropna()
langres=langres.dropna()
livarot=livarot.dropna()
manchego=manchego.dropna()
marscapone=marscapone.dropna()
mimolette=mimolette.dropna()
morbier=morbier.dropna()
mozzarella=mozzarella.dropna()
munster=munster.dropna()
neuchatel=neuchatel.dropna()
parmesan=parmesan.dropna()
pecorino=pecorino.dropna()
provolone=provolone.dropna()
reblochon=reblochon.dropna()
ricotta=ricotta.dropna()
roquefort=roquefort.dropna()
sbrinz=sbrinz.dropna()
sellessurcher=sellessurcher.dropna()
stilton=stilton.dropna()
taleggio=taleggio.dropna()

# %%
df = pd.concat([ambert, beaufort, bleudauvergne, boursin, brie, burrata, cabrales, cambozola, camembert, cantal, chaource, chaumes, cheddar, chevre, comte, crescenza, crottin, danishblue, doublegloucester, edam, epoisses, feta, fontina, gorgonzola, gouda, granapadano, gruyere, havarti, langres, livarot, manchego, 
                marscapone, mimolette, morbier, mozzarella, munster, neuchatel, parmesan, pecorino, provolone, reblochon, ricotta, roquefort, sbrinz,
               sellessurcher, stilton])

# %%
df.set_index('Cheese')
# Out:
#                                        Country of origin  \
# Cheese
# Ambert                                            France
# Beaufort                                          France
# Bleu d'Auvergne                                   France
# Boursin                                           France
# Brie                                              France
# Burrata                          Italy and United States
# Cabrales                                           Spain
# Cambozola Grand Noir                             Germany
# Camembert                                         France
# Cantal                                            France
# Chaource                                          France
# Chaumes                                           France
# Cheddar                                          England
# Chevre                                            France
# Comte                                             France
# ...
